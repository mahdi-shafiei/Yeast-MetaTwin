# %%
import pandas as pd
import numpy as np
import json
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import rdChemReactions
from rdkit.Chem.Draw import rdMolDraw2D
from rdkit.Chem.Draw import IPythonConsole
from IPython.display import SVG, display
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit import DataStructs
from rdkit.Chem import MACCSkeys
import pandas as pd
import rdchiral
import itertools
import pickle
import sys
from tqdm import tqdm 
from rdchiral.main import rdchiralRun, rdchiralRunText, rdchiralReaction, rdchiralReactants
import cobra
from itertools import chain, combinations
import sys
from ast import literal_eval
import multiprocessing
from functools import partial
sys.path.append('../retrosynthesis/')

from common import *

# %%
mnxreac_smile_atom_mapping_rules_file_path = '../../Results/rules/MNXreaction_smiles_atommap_rules_filter.csv'
rxndb_total_info_to_model_path = '../../Results/not_lipid/top50_0.3_re/rxndb_total_info_to_model_top50_0.3.csv'
yeast_met_file = '../../Results/not_lipid/yeast_met_not_lipid.pickle'
yeast870_path = '../../Data/model/yeast-GEM902.yml'
figs8_data_path = '../../Results/source_data/figs11.csv'
figs8_path = '../../Results/Figures/figs11.pdf'

# %%
yeast_total_smiles_extend = load_pickle(yeast_met_file)
print(len(yeast_total_smiles_extend))
# Out:
# 3680

# %%
rules = pd.read_csv(mnxreac_smile_atom_mapping_rules_file_path)
rules = rules[['MNX_ID','product_smiles','ProductSMARTs','RetroRules']]
print(rules.shape)
rules = rules[~rules['ProductSMARTs'].isna()]
print(rules.shape)
rules.head(1)
# Out:
# (21921, 4)
# (21921, 4)
#        MNX_ID                             product_smiles  \
# 0  MNXR100024  [NH4+].[NH3+][C@@H](CCC(=O)[O-])C(=O)[O-]
#
#                                        ProductSMARTs  \
# 0  [C:1]-[C;H0;D3;+0:2](-[O-;H0;D1:5])=[O;D1;H0:4...
#
#                                           RetroRules
# 0  [C:1]-[C;H0;D3;+0:2](-[O-;H0;D1:5])=[O;D1;H0:4...

# %%
mets_total_smiles = yeast_total_smiles_extend

# %%
def smiles_similarity(target_smiles, product_smiles):
    res = 0
    smiles_list = product_smiles.split('.')
    for smiles in smiles_list:
        if 'c' in smiles or 'C' in smiles:  # only match substrates with Carbon
            smile_fps = MACCSkeys.GenMACCSKeys(Chem.MolFromSmiles(smiles))
            target_smiles_fps = MACCSkeys.GenMACCSKeys(Chem.MolFromSmiles(target_smiles))
            tmp_scores = DataStructs.FingerprintSimilarity(smile_fps, target_smiles_fps)
            if tmp_scores>0.3:
                res = 1
        else:pass

    return(res)

# %%
from rdkit import Chem

def match_smarts(target_smiles, ProductSMARTs):
    res = 0  # No match
    smarts_list = ProductSMARTs.split('.')
    
    # Only match substrates with Carbon
    if 'c' in target_smiles or 'C' in target_smiles:
        target_smiles = Chem.MolFromSmiles(target_smiles)
        
        for smarts in smarts_list:
            if target_smiles.HasSubstructMatch(Chem.MolFromSmarts(smarts)):
                res = 1  # Match found
    else:
        pass  # No carbon in target_smiles
    
    return res

# %%
rules
# Out:
#                    MNX_ID                                 product_smiles  \
# 0              MNXR100024      [NH4+].[NH3+][C@@H](CCC(=O)[O-])C(=O)[O-]
#
# [21921 rows x 4 columns]

# %%
def process_smiles(smiles):
    match_num = 0
    match_rule_lst = []
    for index,row in rules.iterrows():
        if match_smarts(smiles, row['ProductSMARTs']) and smiles_similarity(smiles, row['product_smiles']):
            match_num+=1
            match_rule_lst.append(row['MNX_ID'])
    return(smiles, match_num,match_rule_lst)

smiles_pool = multiprocessing.Pool(processes=20)
smiles_match_rules = {'smiles':[],'match_rules':[],'match_rule_lst':[]}

for result in tqdm(smiles_pool.imap_unordered(process_smiles, mets_total_smiles), total=len(mets_total_smiles)):
    smiles_match_rules['smiles'].append(result[0])
    smiles_match_rules['match_rules'].append(result[1])
    smiles_match_rules['match_rule_lst'].append(result[2])
# Out:
# 100%|██████████| 3680/3680 [36:01<00:00,  1.70it/s]

# %%
smiles_match_rules_df = pd.DataFrame(smiles_match_rules)
smiles_match_rules_df
# Out:
#                                                  smiles  match_rules  \
# 0                                          CCCCCOC(C)=O          193
# 1                                    C/C=C/c1ccc(OC)cc1          286
# 2                                        CCc1cccc(C)c1O          664
# 3                                  N=C(N)NCCCC(N)C(=O)O          420
# 4                           NC(=O)N[C@H](CC(=O)O)C(=O)O          972
# ...                                                 ...          ...
# 3675                CC(=O)NC1C(O)C(O)[C@@H](CO)O[C@H]1O         2345
# 3676  CC(C)=CCC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21...         1202
# 3677  CC(C)(COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc...         1903
# 3678  CCCCCCCCC=CCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)C...         2312
# 3679  Nc1c(N[C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O...         2114
#
#                                          match_rule_lst
# 0     [MNXR102250_reverse, MNXR102251_reverse, MNXR1...
# 1     [MNXR104054_reverse, MNXR104991, MNXR106655_re...
# 2     [MNXR100947, MNXR101068, MNXR102261, MNXR10226...
# 3     [MNXR100328, MNXR100390, MNXR100642_reverse, M...
# 4     [MNXR100328, MNXR100348, MNXR100348_reverse, M...
# ...                                                 ...
# 3675  [MNXR100114_reverse, MNXR100129, MNXR100326, M...
# 3676  [MNXR100555, MNXR102250, MNXR102250_reverse, M...
# 3677  [MNXR100064_reverse, MNXR100097, MNXR100098, M...
# 3678  [MNXR100114_reverse, MNXR100129, MNXR100328, M...
# 3679  [MNXR100129, MNXR100277_reverse, MNXR100328, M...
#
# [3680 rows x 3 columns]

# %% [markdown]
# # merge smiles_match_rules_df based on idendical smiles

# %%
len(smiles_match_rules_df['match_rule_lst'].to_list()[0])
# Out:
# 193

# %%
smiles_match_rules_dict = {}
for index, row in tqdm(smiles_match_rules_df.iterrows(), total=len(smiles_match_rules_df)):
    if smiles_has_carbon(row['smiles']):
        # Check if any SMILES in the dictionary matches the current row's SMILES
        matched_key = None
        for smiles in smiles_match_rules_dict.keys():
            if compare_smiles_inchikey(smiles, row['smiles']):
                matched_key = smiles
                break
        
        if matched_key:
            # Append to the existing match_rule_lst if a match is found
            smiles_match_rules_dict[matched_key] += row['match_rule_lst']
        else:
            # Create a new entry in the dictionary if no match is found
            smiles_match_rules_dict[row['smiles']] = row['match_rule_lst']
# Out:
#   9%|▉         | 345/3680 [00:53<13:20,  4.17it/s]
# 100%|██████████| 3680/3680 [41:02<00:00,  1.49it/s]

# %%
smiles_match_rules_dict = {k:list(set(v)) for k,v in smiles_match_rules_dict.items()}

# %%
smiles_match_rules_dict = {k:len(v) for k,v in smiles_match_rules_dict.items()}

# %%
smiles_match_rules_dict
# Out:
# {'CCCCCOC(C)=O': 193,
#  'C/C=C/c1ccc(OC)cc1': 286,
#  'CCc1cccc(C)c1O': 664,
#  'N=C(N)NCCCC(N)C(=O)O': 1399,
#  'NC(=O)N[C@H](CC(=O)O)C(=O)O': 1592,
#  'CC(=O)N1CCC[C@@H]1C(=O)O': 848,
#  'NCC(=O)NC(CCC(=O)O)C(=O)O': 2201,
#  'C[C@](O)(CCO)CC(=O)[O-]': 1852,
#  'O=C([O-])CC[C@@](O)(CC(=O)[O-])C(=O)[O-]': 1677,
#  '[NH3+][C@@H](CCO)C(=O)[O-]': 2342,
#  'NCCC(=O)NC(Cc1cnc[nH]1)C(=O)O': 2055,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)(O)OP(=O)(O)O': 544,
#  'CC[C@@H](C)C(=O)O': 701,
#  'NC1C(O)OC(COP(=O)([O-])O)C(O)C1O': 2965,
#  'O=C(CO)[C@@H](O)[C@H](O)[C@H](O)COP(=O)([O-])[O-]': 2686,
#  'Cc1ccc(O)cc1': 594,
#  'OC[C@H]1O[C@H](O[C@@H]2[C@@H](CO)OC(O)[C@@H](O)[C@H]2O)[C@@H](O)[C@@H](O)[C@@H]1O': 2242,
#  'CCCCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)(O)OCC(N)C(=O)O': 2986,
#  'O=P([O-])([O-])O[C@H]1O[C@H](CO)[C@H](O)[C@H](O)[C@H]1O': 2926,
#  'CC(O)(C(=O)O)c1ccccc1': 708,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)(O)OC(=O)CCCCC2CCSS2)[C@@H](O)[C@H]1O': 2138,
#  'NC(N)=O': 50,
#  'OCCc1c[nH]c2ccccc12': 969,
#  'CC(=O)NC1C(OP(=O)(O)O)OC(CO)C(O)C1O': 2928,
#  'Cc1ccc(C=O)s1': 46,
#  'Nc1nc(NC2OC(COP(=O)([O-])[O-])C([O-])C2[O-])c(N)c(=O)[nH]1': 1308,
#  'OC[C@@H](O)C(O)[C@H](O)CO': 1223,
#  'O=c1ccn(C2CC(O)C(COP(=O)(O)OP(=O)(O)O)O2)c(=O)[nH]1': 2376,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)([O-])OP(=O)([O-])[O-]': 808,
#  'CC(=O)[C@@H](C)O': 220,
#  'N=C(CN=CO)NC1OC(COP(=O)(O)O)C(O)C1O': 2208,
#  'O=C([O-])[C@@H](O)[C@H](O)[C@H](O)[C@@H](O)C(=O)[O-]': 1487,
#  'CC(O)c1ccc(O)cc1': 884,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2437,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)([O-])OP(=O)([O-])[O-]': 808,
#  'COC1=CC(=O)C=C(C/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CC/C=C(\\C)CCC=C(C)C)C1=O': 679,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COC(=O)CCCCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC': 345,
#  'CCc1nc(C(C)C)sc1C': 7,
#  'O[C@H]1OC[C@@H](O)[C@@H](O)[C@@H]1O': 1991,
#  'C=CC(O)CC': 151,
#  'CC(N)C(=O)NC(Cc1cnc[nH]1)C(=O)O': 1905,
#  'O=C(O)[C@H]1C[C@H](O)C=N1': 1394,
#  'Nc1ncnc2c1ncn2[C@H]1C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])O1': 2285,
#  'Nc1nc(NCC([O-])C([O-])C([O-])COP(=O)([O-])[O-])c(N)c(=O)[nH]1': 1310,
#  'CCCCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3258,
#  'CCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3438,
#  'CCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3258,
#  'Cc1cn([C@H]2C[C@H](O)[C@@H](CO)O2)c(=O)[nH]c1=O': 1489,
#  'Cc1cc2c(cc1C)N(CC(O)C(O)C(O)COP(=O)(O)OP(=O)(O)OCC1OC(n3cnc4c(N)ncnc43)C(O)C1O)c1[nH]c(=O)[nH]c(=O)c1N2': 2232,
#  'CCc1ocnc1C': 9,
#  'CCCCCCCCC=O': 322,
#  'COC1=C(O)C(=O)C(C)=C(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)C1=O': 1156,
#  'N[C@H](CSSC[C@@H](N)C(=O)O)C(=O)O': 1509,
#  'Cc1ncc(C[n+]2csc(CCO)c2C)c(N)n1': 688,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)[O-]': 1023,
#  'O=c1[nH]cnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2547,
#  'Nc1ccn(C2CC(O)C(CO)O2)c(=O)n1': 1539,
#  'O=C([O-])CNC(=O)[C@H](CS)NC(=O)CCC(=O)C(=O)[O-]': 1894,
#  'NCCCC(N)C(=O)O': 1716,
#  'CC(N)C(N)CCCCCC(=O)O': 1364,
#  'CCCCCCCC/C=C\\CC(=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3416,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](OP(=O)([O-])[O-])[C@H]1O': 2764,
#  'N#CC(O)c1ccccc1': 184,
#  'C=C(CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O)C(=O)O': 3700,
#  'CC(=O)NC(CO)C(=O)O': 2032,
#  'Cc1ccc(C)c(C)c1C': 29,
#  'C=CC1(C)CCC(C(C)(C)O)O1': 347,
#  'O=C(CO)[C@@H](O)[C@@H](O)[C@H](O)CO': 1690,
#  'Cc1ncsc1CCOP(=O)([O-])[O-]': 1261,
#  'CC(=O)NC(CCC=O)C(=O)O': 1925,
#  'CC(C)=C[C@@H]1C[C@@H](C)CCO1': 188,
#  'N[C@@H](C(=O)O)C(O)C(=O)O': 2236,
#  'CCCCCCCCCCCCCC=C[C@H](O)[C@H](N)CO': 1689,
#  'O=P(O)(O)OC1(CO)O[C@H](CO)[C@@H](O)[C@@H]1O': 2628,
#  'CCCCCCCCCCCCCC[C@@H](O)[C@H](O)[C@H](N)COP(=O)(O)O': 2722,
#  '[NH3+]/C(C(=O)[O-])=C(\\C=C\\C=O)C(=O)[O-]': 1099,
#  '[NH3+][C@@H](CCC(=O)N[C@@H](CSCO)C(=O)NCC(=O)[O-])C(=O)[O-]': 3073,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)
C(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3229,
#  'O=C1O[C@@H](CO)[C@H](O)[C@H]1O': 1822,
#  'CCOC(=O)C(O)C(O)C(=O)OCC': 1159,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OCC(COP(=O)(O)OCC[N+](C)(C)C)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 1160,
#  'O=P([O-])([O-])OC[C@H]1OC(O)[C@H](O)[C@@H](O)[C@@H]1O': 2861,
#  'CCCCCCCCCCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3438,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(CO)C(O)CCCCCCCCCCCCCCC': 1632,
#  'CSSSC': 0,
#  'CC(C)[C@@](O)(CC(=O)[O-])C(=O)[O-]': 1626,
#  'Cc1ncc(CO)c(C=O)c1O': 1613,
#  'CC=CCCCOC(C)=O': 165,
#  'CC1SSC(C)C1=O': 32,
#  'O=C(O)/C=C/Cl': 76,
#  'CCc1nccs1': 10,
#  '[NH3+][C@@H](C=O)C(=O)[O-]': 1435,
#  'C[C@H](NC(=O)CC[C@H](N)C(=O)O)C(=O)O': 2499,
#  'CN1c2c(nc(N)[nH]c2=O)NC[C@@H]1CNc1ccc(C(=O)N[C@@H](CCC(=O)N[C@@H](CCC(=O)N[C@@H](CCC(=O)O)C(=O)O)C(=O)O)C(=O)O)cc1': 1967,
#  'O=P(O)(O)OCC(O)C(O)c1c[nH]c2ccccc12': 2401,
#  'CCCCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O[C@H]1O[C@H](CO)[C@@H](O)C(O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 2788,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H]1CC[C@]2(C)C3=C(CC[C@H]2C1(C)C)[C@]1(C)CC[C@H]([C@H](C)CCC=C(C)C)[C@@]1(C)CC3': 379,
#  'O=C[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)C(=O)O': 1750,
#  '[NH3+][C@@H](CO)C(=O)[O-]': 1904,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(O)COP(=O)(O)O': 2546,
#  'CCOC(=O)CC(O)C(=O)OCC': 1353,
#  'CN1c2c(nc(N)[nH]c2=O)NC[C@@H]1CNc1ccc(C(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-])cc1': 1717,
#  'Nc1c(O)cccc1C(=O)CC(N)C(=O)O': 3017,
#  'CCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3438,
#  'O=C([O-])C[C@H](C(=O)[O-])C(=O)C(=O)[O-]': 2011,
#  'Nc1nc(NC[C@H](O)[C@H](O)[C@H](O)COP(=O)([O-])[O-])c(N)c(=O)[nH]1': 2299,
#  'CCSSCC': 7,
#  'CCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)([O-])[O-]': 3293,
#  'O=C(O)CC(=O)O': 1208,
#  'O=C([O-])[C@H](O)CO': 2104,
#  'CCCCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCC)COP(=O)(O)OCC(O)CO': 2656,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3258,
#  'NC(=O)c1cnccn1': 241,
#  'Oc1ccc(/C=C/c2cc(O)cc(O)c2)cc1': 688,
#  'CCCCCCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)C(O)[C@H]1OP(=O)(O)O': 3256,
#  'OCCc1ccccc1O': 1564,
#  'O=P([O-])([O-])O[C@H]1[C@@H](OP(=O)([O-])[O-])[C@H](OP(=O)([O-])[O-])[C@@H](OP(=O)([O-])OP(=O)([O-])[O-])[C@H](OP(=O)([O-])[O-])[C@H]1OP(=O)([O-])OP(=O)([O-])O': 1352,
#  'C=C(O[C@@H]1C=C(C(=O)[O-])C=C[C@H]1[NH3+])C(=O)[O-]': 717,
#  'CCc1ccc(C)o1': 8,
#  '[NH3+]CC=O': 319,
#  'C=C(C)C1CC=C(C=O)CC1': 355,
#  '[NH3+]CC(=O)NC1OC(COP(=O)([O-])[O-])C(O)C1O': 2520,
#  'CC(C(=O)O)=C(CC(=O)O)C(=O)O': 1376,
#  'Nc1c(C(=O)N[C@@H](CC(=O)[O-])C(=O)[O-])ncn1[C@@H]1O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2678,
#  'CCCCCCCCCCCCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3256,
#  'Cc1ncc(C[n+]2csc(CCOP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])c2C)c(N)n1': 1321,
#  'CC(=O)C=CC=C(C)C': 96,
#  'CC(C)CO': 285,
#  'CCCCCCCCCCCCCCCCCC=CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@@H]1O[C@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3262,
#  'CCCCCCCCCCCCCCCCCCCCCC(O)C(O)C(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(CO)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2817,
#  'O=C(c1ccccc1)[C@H](O)c1ccccc1': 339,
#  'Cc1cc2c(cc1C)N(CC(O)C(O)C(O)COP(=O)(O)O)c1[nH]c(=O)[nH]c(=O)c1N2': 2332,
#  'CO[C@@H]1O[C@H](CO)[C@H](O)[C@H](O)[C@H]1O': 1797,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(CO)C(O)C(O)CCCCCCCCCCCCCC': 1835,
#  'CCCc1nc(C)c(C)s1': 11,
#  'CC(C)=CCC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21C)[C@@]1(C)CCC(=O)CC1CC3': 532,
#  'COC1=C(OC)C(=O)C(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)=C(C)C1=O': 641,
#  'COc1cc(C(=O)[O-])ccc1O': 1644,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(O)C(O)C(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(COP(=O)(O)OC2C(O)C(O)C(O)C(O)C2O)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2580,
#  'Nc1ncnc2c1ncn2C1CC2OP(=O)(O)OCC2O1': 460,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](CO)[C@H](O)CCCCCCCCCCCCCCC': 1741,
#  'Cc1ccc2cccc(C)c2c1': 32,
#  'NCCO': 805,
#  'O=C([O-])/C=C/C(=O)[O-]': 766,
#  'NC(CS)C(=O)NCC(=O)[O-]': 2219,
#  'N=c1c2ncn([C@@H]3O[C@H](COP(=O)(O)OP(=O)(O)OP(=O)(O)O)[C@@H](O)[C@H]3O)c2ncn1C1O[C@H](COP(=O)(O)O)[C@@H](O)[C@H]1O': 2260,
#  'O=C[C@H](O)CO': 1351,
#  'O=C([O-])[C@@H](O)[C@H](O)[C@@H](O)[C@H](O)CO': 2390,
#  'Cc1c2[nH]c(c1CCC(=O)[O-])Cc1[nH]c(c(CCC(=O)[O-])c1C)Cc1[nH]c(c(CCC(=O)[O-])c1C)Cc1[nH]c(c(C)c1CCC(=O)[O-])C2': 1711,
#  'CCCCCC/C=C\\CCCCCCCC(=O)SCCN=C(O)CCN=C(O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3247,
#  '[NH3+][C@@H](CCc1ncc(C[C@H]([NH3+])C(=O)[O-])[nH]1)C(=O)[O-]': 2189,
#  'O=c1[nH]cnc2nc[nH]c12': 293,
#  '[NH2+]=C(NCCC[C@H]([NH3+])C(=O)[O-])NP(=O)([O-])[O-]': 2553,
#  'CCCC(O)CC(=O)OCC': 1220,
#  'O=C([O-])C=C1C=CC(=O)O1': 878,
#  'O=C(CO)[C@@H](O)[C@H](O)CO': 1645,
#  'CCCCO': 559,
#  'O=C([O-])[C@@H]1CCC=N1': 596,
#  'CC[C@H](C)[C@@H]([NH3+])C(=O)[O-]': 1363,
#  'Nc1nc2c(ncn2C2CC(O)C(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O2)c(=O)[nH]1': 2305,
#  'CC(=O)O[C@@H](CC(=O)[O-])C[N+](C)(C)C': 751,
#  'Nc1nc2ncc(CNc3ccc(C(=O)NC(CCC(=O)O)C(=O)O)cc3)nc2c(=O)[nH]1': 1779,
#  'CCCCCCC=CCCCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC': 344,
#  'Cc1cc2nc3c(=O)[nH]c(=O)nc-3n(CC(O)C(O)C(O)CO)c2cc1C': 1639,
#  'CC(C)CCC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@@]21C': 788,
#  'CC[C@@H](C)CO': 371,
#  'O=C[C@@H](O)[C@H](O)COP(=O)(O)O': 2405,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)(O)OC[C@@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 2255,
#  'NC(Cc1ccc(O)cc1)C(=O)O': 2727,
#  'O=C([O-])C(=O)CS': 1928,
#  'CCCCCCCCCCCC[C@@H](O)[C@@H](O)[C@@H](N)CO': 1545,
#  'CC(=O)OCC1OC(Oc2cc3c(O)cc(O)cc3[o+]c2-c2cc(O)c(O)c(O)c2)C(O)C(O)C1O': 2828,
#  'CC(O)C(=O)SCC(C(=O)O)C(N)C(=O)O': 1876,
#  'O=C(O)CCC(O)C(=O)O': 2040,
#  'Nc1ncnc2c1ncn2C1OC(COP(=O)(O)O)C(OP(=O)(O)O)C1O': 2243,
#  'CCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3258,
#  'C[C@H](C[NH3+])C(=O)[O-]': 1178,
#  'Cc1ncc(CO)c(N)n1': 765,
#  'CC(=O)Oc1ccc(O)cc1': 772,
#  'C[NH2+]C(CCc1nc(C[C@H]([NH3+])C(=O)[O-])c[nH]1)C(=O)[O-]': 2179,
#  'Nc1nc2c(c(=O)[nH]1)N=C(CNc1ccc(C(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-])cc1)CN2': 1696,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\COP(=O)([O-])OP(=O)([O-])[O-]': 808,
#  'CCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)(O)OCC(N)C(=O)O': 1306,
#  'O=C[O-]': 119,
#  'Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)C(O)C1O': 2269,
#  'CCCCCCCC/C=C\\CCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3256,
#  'CC=O': 133,
#  'C=C(C)CCOP(=O)([O-])OP(=O)([O-])[O-]': 648,
#  'COc1cc(/C=C/C(=O)O[C@H](C(=O)O)[C@H](O)C(=O)O)ccc1O': 2214,
#  'CCCCCC/C=C\\CCCCCCCCCC(=O)OC[C@H](COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2ccc(N)nc2=O)C(O)[C@H]1O)OC(=O)CCCCCCCCC/C=C\\CCCCCC': 2359,
#  'C=CC=CC(C)OCC': 10,
#  'CC(C)CCCO': 639,
#  'CC(C)=CCC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21C)[C@@]1(C)CC[C@H](O)C(C)(C)[C@@H]1CC3': 855,
#  'NCCCCN': 312,
#  'Nc1nc2c(ncn2[C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c(=O)[nH]1': 2245,
#  'Nc1c(NC[C@H](O)[C@H](O)[C@H](O)CO)[nH]c(=O)[nH]c1=O': 1398,
#  'CCCCC=CC=O': 243,
#  'Cc1ncc(C[n+]2csc(CCOP(=O)(O)O)c2C)c(N)n1': 1312,
#  'CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-])[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)CCC(=O)[O-]': 3676,
#  'CC(O)C(O)C1CNc2ncnc(O)c2N1': 1258,
#  'CCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3258,
#  'Nc1ncnc2[nH]cnc12': 218,
#  'C1=Cc2cc3ccc(cc4ccc(cc5nc(cc1n2)C=C5)[nH]4)[nH]3': 35,
#  '[NH3+][C@H](CCS)C(=O)[O-]': 1853,
#  'OCC1OC(OC2OC(CO)C(O)C(OC3OC(CO)C(O)C(O)C3O)C2OC2OC(CO)C(O)C(O)C2O)C(O)C(O)C1O': 1769,
#  'O=C([O-])COP(=O)([O-])[O-]': 1565,
#  'CC(C)(COP(=O)([O-])[O-])[C@@H](O)C(=O)NCCC(=O)[O-]': 3022,
#  'CC1=CCC2(CC1)C(=C(C)C)CC[C@@H]2C': 178,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)(O)OC[C@H](O)COP(=O)(O)OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 2255,
#  'CC/C=C\\CCOC(C)=O': 230,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)OC[C@@H](O)COP(=O)([O-])OC[C@H]([NH3+])C(=O)[O-]': 3361,
#  'CCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3446,
#  'C[n+]1cn(C2OC(COP(=O)(O)O)C(O)C2O)c2nc(N)[nH]c(=O)c21': 2248,
#  'CCCCCCCCCC(C)=O': 410,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@@H](CO)COC(=O)CCCCCCCCCCCCCCC': 1302,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2437,
#  'C[Se]CCC(N)C(=O)O': 1508,
#  'NC(=O)c1ncn([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c1N': 2186,
#  'Nc1ccccc1C(=O)C[C@@H](N)C(=O)O': 2468,
#  'O=P([O-])([O-])OC[C@H]1O[C@H](O[C@]2(CO)O[C@H](CO)[C@@H](O)[C@@H]2O)[C@H](O)[C@@H](O)[C@@H]1O': 2625,
#  'O=C(O)C=C(CCC(=O)O)C(=O)O': 1315,
#  'CCCCCCCCC(C)CC': 65,
#  'CC1=C(C=O)C(C)(C)CCC1': 402,
#  'O=C(O)c1ccc2ccccc2n1': 392,
#  'CSCCC(NC(=O)CN)C(=O)O': 2499,
#  'NC(=O)c1ccccc1': 49,
#  'Cc1ncccc1CCO': 698,
#  'CCCCCCCCCCCCCCCCCCCCCC(=O)[O-]': 723,
#  'Cc1nc2c(=O)[n-]c(=O)nc-2n(C[C@H](O)[C@H](O)[C@H](O)CO)c1C': 1543,
#  'OCC1OC(Oc2cc3c(O)cc(O)cc3[o+]c2-c2cc(O)c(O)c(O)c2)C(O)C(O)C1O': 2896,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/Cc1cc(C(=O)[O-])cc(O)c1O': 1815,
#  'CC(=O)OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1O': 2093,
#  'O=P(O)(O)OC[C@H]1O[C@@](O)(CO)[C@@H](O)[C@H]1O': 2823,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O[C@@H]2O[C@H](COC(=O)/C=C\\c3ccc(O)cc3)[C@@H](O)[C@H](O)[C@H]2O)cc(O)c1O': 3008,
#  'O=C(O)c1ccccc1NC1OC(COP(=O)(O)O)C(O)C1O': 2520,
#  'O=C[C@H](O)[C@H](O)[C@H](O)COP(=O)([O-])[O-]': 2489,
#  'C=CC1(C)CCCC(C)(C)O1': 111,
#  'NC(=O)c1ccc[n+](C2OC(CO)C(O)C2O)c1': 1579,
#  'CCCCCCC=CCCCCCCCCCC(=O)OC(COC(=O)CCCCCCCC=CCCCCCCCC)COC(=O)CCCCCCCC=CCCCCCCCC': 344,
#  'C[C@@H](O)[C@@H](O)C1=Nc2c([nH]c(N)nc2=O)NC1': 1110,
#  'O=C(O)CO': 1561,
#  'CC(=O)NCCC[NH2+]CCCC[NH2+]CCC[NH3+]': 500,
#  'Nc1nc2c([nH]c(=O)n2[C@H]2C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])O2)c(=O)[nH]1': 2317,
#  'O=C([O-])CCc1c2[nH]c(c1CC(=O)[O-])Cc1[nH]c(c(CC(=O)[O-])c1CCC(=O)[O-])Cc1[nH]c(c(CC(=O)[O-])c1CCC(=O)[O-])Cc1[nH]c(c(CCC(=O)[O-])c1CC(=O)[O-])C2': 1661,
#  'COc1c2c(cc(O)c1-c1cc3ccccc3o1)OCO2': 996,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O)C(O)CCCCCCCCCCCCCCC': 2443,
#  'O=C(O)C(O)C(O)C(O)C(O)COP(=O)(O)O': 3059,
#  'CCC(C)CCO': 626,
#  'C[C@@H](N)C(=O)NCC(=O)O': 1948,
#  'O=C(O)[C@H]1O[C@@H](Oc2c(-c3cc(O)c(O)c(O)c3)oc3cc(O)cc(O)c3c2=O)[C@H](O)[C@@H](O)[C@@H]1O': 2582,
#  'COc1cc(-c2oc3cc(O)cc(O)c3c(=O)c2O[C@H]2O[C@@H](CO)[C@H](O)[C@@H](O)[C@@H]2O)ccc1O': 3002,
#  'CCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3438,
#  'COc1cccc(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)c1O': 965,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(COP(=O)(O)OC2C(O)C(O)C(O)C(O)C2O)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2521,
#  'Nc1ccn(C2OC(COP(=O)(O)O)C(O)C2O)c(=O)n1': 2598,
#  'CCCCCCC=CCCCCCCCC(=O)OC(COC(=O)CCCCCCCC=CCCCCCCCC)COP(=O)(O)OCC(N)C(=O)O': 2986,
#  'C[C@H](O)[C@@H]([NH3+])C(=O)[O-]': 1723,
#  'CCCCCCCCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3438,
#  'CC(C(=O)O)C(O)(CC(=O)O)C(=O)O': 1637,
#  'CC(C)=CCC[C@H](C)[C@@H]1CC[C@H]2C3=C(CC[C@]12C)[C@@]1(C)CC[C@H](O)[C@@](C)(C(=O)O)[C@H]1CC3': 1867,
#  'CCCCCCCCCCCCCCCCCCCC(=O)O': 1023,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](OC2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC': 2544,
#  'CCCCCCCC(=O)[O-]': 722,
#  'NC(=O)c1ncn(C2OC(COP(=O)([O-])[O-])C(O)C2O)c1N=CNC1OC(COP(=O)([O-])[O-])C(O)C1O': 2087,
#  'O=C(O)[C@H]1O[C@@H](Oc2c(-c3ccc(O)c(O)c3)oc3cc(O)cc(O)c3c2=O)[C@H](O)[C@@H](O)[C@@H]1O': 2595,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(O)C(O)C(=O)NC(COP(=O)([O-])OC1C(O)C(O)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2490,
#  'O=CC(=O)[O-]': 703,
#  'C=CC1=C(C)c2cc3[nH]c(cc4nc(cc5[nH]c(cc1n2)c(C)c5CCC(=O)[O-])C(CCC(=O)[O-])=C4C)c(C)c3C=C': 1753,
#  'O=C(O)C[C@H](Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)(O)O)[C@@H](O)[C@H]1O)C(=O)O': 2736,
#  '[NH3+][C@@H](CC(=O)[O-])C(=O)[O-]': 1858,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H]1CC[C@]2(C)C3=C(CC[C@H]2C1(C)C)[C@]1(C)CC[C@H]([C@H](C)CCC=C(C)C)[C@@]1(C)CC3': 379,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2454,
#  'CC(C)c1ccc(CO)cc1': 235,
#  'CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-])[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)C(=O)[O-]': 3664,
#  'CCc1ccccc1C=CC(=O)[O-]': 635,
#  'O=C([O-])c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c1': 2420,
#  'Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1': 1496,
#  'CC(C(=O)[O-])C(=O)[O-]': 985,
#  'CSCCC(=O)C(=O)COP(=O)([O-])[O-]': 1700,
#  'O=C(CO)COP(=O)(O)O': 2186,
#  'CCCCCCCCCCCCCCC(O)C=O': 1134,
#  'C=COCC': 0,
#  'CCCCCCCCC=CCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3240,
#  'CCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3438,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCOP(=O)([O-])OP(=O)([O-])[O-]': 806,
#  'CCCCCCCC/C=C\\CCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@@H](O)[C@H]1OP(=O)(O)O': 3279,
#  'C/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3236,
#  'CCCCC1OC(=O)CC1C': 286,
#  'CC(=O)[O-]': 620,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)(O)O)OC(=O)CCCCCCCC=CCCCCCC': 1469,
#  'CCc1ccccc1C': 36,
#  'CCCCCCCCCC(=O)CC(=O)O': 1482,
#  'CCC(C)(O)C(O)C(=O)[O-]': 1968,
#  'CC(=O)NCCC[NH2+]CCCC[NH3+]': 494,
#  'CCOc1cc(C=O)ccc1O': 926,
#  'CCCCCCCCCCCCCCCCOCC(COP(=O)(O)OCCN)OC(=O)CCCCCCCCCCCCCCC': 1496,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1OC1OC(CO)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2762,
#  'O=C(O)C(=O)C(O)c1ccccc1': 1755,
#  'CCCCCCCCCCCCCCCCCCCCCCC[C@@H](O)[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](OC2O[C@H](CO)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2817,
#  'C=CC(=O)[O-]': 471,
#  'O=c1nc[nH]c2c1ncn2C1O[C@H](CO)[C@@H](O)[C@@H]1O': 1804,
#  'CCCCCCCCCCCCCCCC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3438,
#  'COc1cc(C2=C(OC3OC(CO)C(O)C(O)C3O)C3=CCOc4cc(O)cc(c43)[OH+]2)cc(OC)c1O': 2649,
#  'CC(C)(CO)[C@@H](O)C(=O)[O-]': 1778,
#  'Cc1ncc(C[n+]2c(C(C)O)sc(CCOP(=O)(O)OP(=O)(O)O)c2C)c(N)n1': 1993,
#  'CCCCCCCCC=CCCCCCCCC(=O)OCC(O)COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O': 2522,
#  'CCCCCC1CCCC(=O)O1': 238,
#  'CCCCCCC=CC=CCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3236,
#  'CC1=CCCC(C)(C)C1C=O': 347,
#  'CCCCCCCC/C=C\\CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)C(O)[C@H]1OP(=O)(O)O': 3229,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COC(=O)CCCCCCC/C=C\\CCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 344,
#  'O=c1ccn([C@H]2C[C@H](O)[C@@H](CO)O2)c(=O)[nH]1': 1532,
#  'Nc1ccn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OCC[NH3+])[C@@H](O)[C@H]2O)c(=O)n1': 2292,
#  'Oc1cc(O)c2cc(O)c(-c3ccc(O)c(O)c3)[o+]c2c1': 1094,
#  'CCC[C@@H](N)C(=O)O': 1579,
#  'CC(=O)CC(=O)[O-]': 1019,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O': 2450,
#  'O=CC=CCl': 11,
#  'COc1cc(C23Oc4cc(O)ccc4C(C2OC2OC(CO)C(O)C(O)C2O)C(C)(C(C)=O)O3)cc(O)c1O': 3222,
#  'CCCCCCCCCC=CC=CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3262,
#  'O=S(=O)([O-])CCO': 498,
#  'C=C(CCC(C)C1CCC2C3=CC=C4CC(O)CCC4(C)C3CCC21C)C(C)C': 795,
#  'CC(=O)N[C@@H](Cc1ccccc1)C(=O)[O-]': 1528,
#  'N=C(CC(=O)O)C(=O)O': 1106,
#  'CC(C)=CCCC(C)=CCCC(C)=CC=O': 525,
#  'O=C([O-])[C@@H](COP(=O)([O-])[O-])OP(=O)([O-])[O-]': 2259,
#  'COc1cc(-c2[o+]c3cc(O)cc([O-])c3cc2O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)cc(OC)c1O': 3105,
#  'CC(=O)C[NH3+]': 322,
#  'Cc1ccc(C(=O)O)c(C)c1': 331,
#  'COC(=O)CCSC': 189,
#  '[NH3+][C@@H](CCC(=O)N[C@@H](CSSC[C@H](NC(=O)CC[C@H]([NH3+])C(=O)[O-])C(=O)NCC(=O)[O-])C(=O)NCC(=O)[O-])C(=O)[O-]': 2469,
#  'Cc1cc2c3c(c1C)C(C)(C)CCN3c1c([nH]c(=O)[nH]c1=O)N2C[C@H](O)[C@H](O)[C@H](O)COP(=O)(O)O': 1571,
#  'Cc1cncc(C)n1': 37,
#  'C[N+](C)(C)CCCC=O': 190,
#  'NC(Cc1ccc(OP(=O)(O)O)cc1)C(=O)O': 3009,
#  'Nc1nc2c(ncn2[C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)[nH]1': 1394,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CC/C(C)=C\\CCC(C)CCOP(=O)([O-])O[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O': 3063,
#  'C=CC(C)(O)C/C=C/C(=C)C': 290,
#  'Nc1nc2c(c(=O)[nH]1)N1CN(c3ccc(C(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-])cc3)C[C@H]1CN2': 1585,
#  'CCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O)C(O)C(O)CCCCCCCCCCCCCC': 2454,
#  'Cc1cn(C2CC(OP(=O)(O)O)C(CO)O2)c(=O)[nH]c1=O': 2401,
#  'O=C([O-])C(=O)[C@@H](O)[C@H](O)[C@H](O)COP(=O)([O-])[O-]': 3384,
#  'CCCCCCCC=CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3256,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2OC2OC(COC(=O)C=Cc3ccc(O)c(O)c3)C(O)C(O)C2O)cc(OC)c1O': 3039,
#  'CC(C)CCOC(=O)Cc1ccccc1': 255,
#  'CCCc1cccc(OC)c1OC': 427,
#  'Nc1nc2c(ncn2[C@H]2C[C@H](O)[C@@H](COP(=O)([O-])[O-])O2)c(=O)[nH]1': 2209,
#  'COC(=O)Cc1ccccc1': 131,
#  'CC(=O)N[C@@H](CCC(N)=O)C(=O)O': 2004,
#  'N#C[C@@H](N)CCC(=O)O': 257,
#  'CCCCc1ccccc1': 31,
#  'O=C(O)c1ccc[n+](C2OC(CO)C(O)C2O)c1': 1783,
#  'Nc1ncnc2c1ncn2C1CC(O)C(CO)O1': 1262,
#  'COc1ccccc1': 287,
#  'CCCCCCCCCCCCCCCCCC(=O)OCC(=O)COP(=O)(O)O': 1685,
#  'CCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3256,
#  'O=C(CO)[C@H](O)[C@H](O)COP(=O)([O-])[O-]': 2737,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OS(=O)(=O)[O-])[C@@H](OP(=O)([O-])[O-])[C@H]1O': 2160,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)NC(CO)C(O)CCCCCCCCCCCCCCC': 1632,
#  'C[N+](C)(C)CC(O)CC(=O)[O-]': 970,
#  'NC(=O)CC[C@H](NC(=O)C[NH3+])C(=O)[O-]': 2236,
#  'Nc1ncnc2c1ncn2C1OC(CSCCC(N)C(=O)O)C(O)C1O': 2984,
#  'Nc1c(C(=O)[O-])[nH+]cn1[C@@H]1O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2282,
#  'C=C(CCC(C)C1CCC2C3=C(CCC21C)C1(C)CCC(OC(=O)CCCCCCCC=CCCCCCC)CC1CC3)C(C)C': 316,
#  'C[N+](C)(C)CCCC(=O)[O-]': 605,
#  'CCCCCCCC/C=C/CCCCCCCC(=O)OC[C@H](COP(=O)(O)OCCN(C)C)OC(=O)CCCCCCC/C=C/CCCCCCCC': 1199,
#  'CC(O)CO': 1040,
#  'C=CC1=C(C)C2=Cc3c(C=C)c(C)c4n3[Fe-2]35n6c(c(C)c(CCC(=O)[O-])c6=CC6=[N+]3C(=C4)C(C)=C6CCC(=O)[O-])=CC1=[N+]25': 1268,
#  'CC1CC=C2C(C)(C)CC=CC2(C)O1': 151,
#  'C[N+](C)(C)CC(=O)[O-]': 457,
#  'CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3295,
#  'CCOC(=O)C(C)O': 955,
#  'CCCCCC=CC=CC=O': 273,
#  'CCCC(O)CC(=O)O': 1873,
#  'CC(C)C(=O)C(=O)[O-]': 1104,
#  'Cn1cncc1C[C@H]([NH3+])C(=O)[O-]': 1833,
#  'CC[C@H](C)C=O': 160,
#  'CCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3266,
#  'NC(=O)NC(=O)[O-]': 380,
#  'Cc1ncc(COP(=O)(O)O)c(CN)c1O': 1915,
#  'Cc1c[nH]c(=O)nc1N': 326,
#  'NC(=[NH2+])NCCCC(N)=O': 153,
#  'C/C=C(/C)C1CCC(C)(C)O1': 138,
#  'O=C(O)c1cc(O)c(O)c(O)c1': 1639,
#  'CCCCCCC[C@H]1CCC(=O)O1': 225,
#  '[NH3+][C@@H](C[SeH])C(=O)[O-]': 1389,
#  'C[C@H]([NH3+])C(=O)N[C@@H](CCC(=O)[O-])C(=O)[O-]': 2185,
#  'CC(=O)Oc1ccccc1': 256,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O)([O-])[O-]': 1427,
#  'Cc1cn(C2CC(O)C(COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O2)c(=O)[nH]c1=O': 2289,
#  'O=c1ccn([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c(=O)[nH]1': 2329,
#  'CCCCCCCCCCCCCCCC(O)C(N)COP(=O)(O)O': 2569,
#  'OCCO': 626,
#  'Nc1c2ncn(C3OC(COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])O)C(O)C3O)c2nc[n+]1C1OC(COP(=O)([O-])O)C(O)C1O': 2008,
#  'OC[C@H]1OC(CO)(O[C@@H]2O[C@H](CO[C@@H]3O[C@H](CO)[C@H](O)[C@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C
)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(/C)CC/C=C(\\C)CC/C=C(\\C)CCC=C(C)C)O[C@H](CO)[C@@H](O)[C@@H]1O': 3097,
#  'CCCCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)NC(CO)C(O)C(O)CCCCCCCCCCCCCC': 1855,
#  'O=c1[nH]cnc2c1ncn2[C@H]1C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])[O-])O1': 2321,
#  'CCCC(S)CCOC(C)=O': 356,
#  'CC1CCCC2(C)CCCCC12O': 387,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2O[C@@H]2OC(CO)[C@@H](O)C(O)C2O)cc(O)c1O': 2883,
#  'CC(CCC[C@@H](C)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@@]21C)[C@@]1(C)CC[C@H](O)C[C@@H]1C[C@H]3O)C(=O)O': 1965,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O': 2495,
#  'O=C(O)C1C=CC=[N+]([C@@H]2O[C@H](COP(=O)([O-])O)[C@@H](O)[C@H]2O)C1': 1987,
#  'O=CC[C@H](O)[C@H](O)CO': 1573,
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)[C@H](O)[C@H]1O': 1268,
#  'CCc1ccc(C(C)=O)cc1': 99,
#  'CC(O)(CCOP(=O)(O)OP(=O)(O)O)CC(=O)O': 2664,
#  'C=C(O[C@@H]1CC(C(=O)[O-])=C[C@@H](OP(=O)([O-])[O-])[C@H]1O)C(=O)[O-]': 2707,
#  'OCC1CCCC1': 515,
#  'O=P([O-])([O-])O[C@@H]1C[C@H](O)[C@@H](CO)O1': 2979,
#  'CCCCC/C=C\\C/C=C\\C=C\\C=C\\[C@@H]1O[C@H]1CCCC(=O)[O-]': 1323,
#  'O=C([O-])/C=C/c1ccc(O)cc1': 1429,
#  'Nc1cc[nH]c(=O)n1': 376,
#  'COc1cc(C(=O)O)cc(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)c1O': 1854,
#  'C[C@H](O)CC(=O)SCCN=C(O)CCN=C(O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)(O)O': 3274,
#  'CCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)NC(COP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O)C(O)CCCCCCCCCCCCCCC': 1804,
#  'C[S+](CCC(N)C(=O)[O-])CC1OC(n2cnc3c(N)ncnc32)C(O)C1O': 3006,
#  'O=C(O)CCC(=O)C(=O)O': 2170,
#  'CCCCCC/C=C/CCCCCCCC(=O)OC[C@H](COP(=O)([O-])OCC[N+](C)(C)C)OC(=O)CCCCCCC/C=C/CCCCCC': 1090,
#  'O=C([O-])/C=C\\C(=O)CC(=O)[O-]': 1517,
#  'CCc1ccc(O)cc1': 573,
#  'O=C([O-])/C=C\\C(=O)CC(=O)CC(=O)[O-]': 1622,
#  '[NH3+][C@@H](Cc1c[nH]c2ccccc12)C(=O)[O-]': 2152,
#  'CCCCCCCCCCCCCCCCCCCCCC(O)C(O)C(=O)N[C@@H](COP(=O)(O)O[C@H]1[C@H](O[C@@H]2O[C@H](COP(=O)(O)O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)C(O)CCCCCCCCCCCCCC': 2580,
#  'Nc1c(NC[C@H](O)[C@H](O)[C@H](O)COP(=O)([O-])[O-])[nH]c(=O)[nH]c1=O': 2259,
#  'NC(=O)C[C@H]([NH3+])C(=O)[O-]': 1996,
#  'Cc1cc2nc3c(=O)[nH]c(=O)nc-3n(CC(O)C(O)C(O)COP(=O)(O)OP(=O)(O)OCC3OC(n4cnc5c(N)ncnc54)C(O)C3O)c2cc1C': 1566,
#  'CCCCCCCC/C=C\\CCCCCCCC(=O)O[C@H]1CC[C@@]2(C)C(=CC=C3[C@@H]2CC[C@@]2(C)[C@H]3CC[C@@H]2[C@H](C)/C=C/[C@H](C)C(C)C)C1': 329,
#  'O=P([O-])([O-])OC[C@H]1OC(OC2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)[C@H](O)[C@@H](O)[C@@H]1O': 2574,
#  'C[C@H](CCC(=O)NCCS(=O)(=O)O)[C@H]1CC[C@H]2[C@@H]3[C@@H](O)C[C@@H]4C[C@H](O)CC[C@]4(C)[C@H]3C[C@H](O)[C@@]21C': 1405,
#  'CC(C)(C)C1CCC(=O)CC1': 364,
#  'CCOC(C)OCC': 24,
#  'CC(=O)NC(CS)C(=O)O': 1766,
#  'O=COCC(=O)OCCOP(=O)(O)OC1C(O)C(O)C(OP(=O)(O)O)C(O)C1O': 1651,
#  'NC(=O)c1ncn(C2OC(COP(=O)(O)O)C(O)C2O)c1N=CO': 2163,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)([O-])OP(=O)([O-])[O-]': 808,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCC': 345,
#  'O=C[C@H](O)COP(=O)([O-])[O-]': 2301,
#  'NC(=O)c1ccc[n+](C2OC(COP(=O)([O-])O)C(O)C2O)c1': 2309,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)(O)OC[C@H](N)C(=O)O)OC(=O)CCCCCCC/C=C\\CCCCCCCC': 1305,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])[O-]': 1295,
#  'NCCS(=O)(=O)O': 334,
#  'CC(C)C[C@H]([NH3+])C(=O)[O-]': 1362,
#  'CCCCCCCCCCCCCCCCCC(=O)OCC(O)COP(=O)(O)O': 2488,
#  'CCOC(=O)CCC(C)=O': 552,
#  'O=C([O-])[C@@H]1CCC[NH2+]1': 1164,
#  'CC(O)C(C)(C)C': 88,
#  'CC(=O)[C@H](O)COP(=O)([O-])[O-]': 2423,
#  'CC(C)CC=O': 180,
#  'C[N+](C)(C)CCOP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2ccc(N)nc2=O)[C@H](O)[C@@H]1O': 2085,
#  'CCC(C)C(=O)C(=O)O': 1441,
#  'CN1CN=c2c(ncn2[C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)=C1N': 1092,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@@H](O)COP(=O)(O)OC[C@H](N)C(=O)O': 1685,
#  'O=C(O)CNC(=O)Cc1ccccc1': 1874,
#  'CCC(C)COC(C)=O': 104,
#  'O=C([O-])[C@@H]1C[C@@H](O)C[NH2+]1': 2022,
#  'CC(=O)C(=O)[O-]': 1197,
#  'CCCCC/C=C\\C/C=C/CCCCCCCC(=O)O': 1073,
#  'CCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O[C@H]1O[C@H](CO)[C@@H](O)C(O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 2788,
#  'CC(=O)OCC[C@H]([NH3+])C(=O)[O-]': 2468,
#  'CCOC(=O)[C@@H](N)CCSC': 328,
#  'C#N': 15,
#  'OCc1cccc(Cl)c1': 186,
#  'O=C(O)C(=O)CC(O)C(O)C(O)COP(=O)(O)O': 3450,
#  'CCCCCCCC/C=C/CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCCCC)COP(=O
nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])OC[C@H]2O[C@@H](n3cnc4c(N)ncnc43)[C@H](O)[C@@H]2O)[C@@H](O)[C@H]1O': 1974,
#  'C[C@@H]1NC(=O)N[C@@H]1CCCCCC(=O)[O-]': 1729,
#  'O=P([O-])([O-])OC[C@H]1O[C@@H](OP(=O)([O-])[O-])[C@H](O)[C@@H](O)[C@@H]1O': 2714,
#  'Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OCC2OC([n+]3cccc(C(=O)O)c3)C(O)C2O)C(O)C1O': 2269,
#  '[NH3+][C@H](COP(=O)([O-])[O-])Cc1c[nH]cn1': 1521,
#  'Cc1ccc2c(c1)C=CCC2(C)C': 112,
#  'CC(C)=CCC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21C)[C@@]1(C)CC[C@H](O)[C@@H](C)[C@@H]1CC3': 839,
#  'C=C(CC[C@@H](C)[C@H]1CC[C@H]2C3=C(CC[C@@]21C)[C@@]1(C)CC[C@H](O)C[C@@H]1CC3)C(C)C': 756,
#  'O=C([O-])/C=C/c1ccc(O)c(O)c1': 1728,
#  'Nc1nc2c(ncn2C2CC(O)C(COP(=O)(O)OP(=O)(O)O)O2)c(=O)[nH]1': 2320,
#  'CCCCCCCCCCCCCCCC(=O)C(N)CO': 1604,
#  'NC(=O)CCCC[C@@H]1CCSS1': 162,
#  'CCCCCCCCC=CCCCCCC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)([O-])[O-]': 3196,
#  '[NH3+][C@@H](CCOP(=O)([O-])[O-])C(=O)[O-]': 3050,
#  'CCCCC=CC=CC=O': 242,
#  'CCCCCCCCCCCCCCCC(=O)OC[C@@H](O)COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O': 2482,
#  'CCCCCCCCCCCCCCCC=O': 322,
#  '[NH3+][C@@H](CCCC=O)C(=O)[O-]': 1952,
#  'Nc1nc2c(ncn2C2CC(O)C(CO)O2)c(=O)[nH]1': 1459,
#  'Nc1ccn(C2CC(O)C(COP(=O)(O)O)O2)c(=O)n1': 2302,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COC(=O)CCCCCCCCCCCCCCCCC)OC(=O)CCCCCCCCCCCCCCCCC': 345,
#  'O=C(O)CNC(=O)c1ccccc1O': 1699,
#  'O=c1[nH]cnc2c1ncn2C1CC(O)C(CO)O1': 1518,
#  'CC(=O)[C@@H](O)[C@H](O)COP(=O)([O-])[O-]': 2526,
#  'CC(C)c1ccc(C=O)cc1': 162,
#  'C[Se]C[C@@H](N)C(=O)O': 1263,
#  'O=CC[C@H](O)[C@H](O)COP(=O)(O)O': 2430,
#  'CCCCCCC[C@@H](O)CC(=O)[O-]': 1834,
#  'CC(C)c1ccccc1': 18,
#  'NC(C(=O)O)C(O)COP(=O)(O)O': 3381,
#  'CC(C)(CO)C(=O)C(=O)[O-]': 1994,
#  'O=c1c(O)c(-c2ccc(O)cc2)oc2cc(O)cc(O)c12': 1114,
#  'O=c1c([O-])c(-c2cc(O)c(O)c(O)c2)oc2cc(O)cc(O)c12': 1134,
#  'CC(=O)OCC(N)C(=O)O': 2084,
#  'CC1(CC(=O)O)C2=Cc3[nH]c(c(CCC(=O)O)c3CC(=O)O)Cc3[nH]c(c(CC(=O)O)c3CCC(=O)O)C=C3N=C(C=C(N2)C1CCC(=O)O)C(C)(CC(=O)O)C3CCC(=O)O': 1035,
#  'Nc1nc2c(c(=O)[nH]1)N=C(CO)CN2': 884,
#  'Cc1c2[nH]c(c1CCC(=O)[O-])Cc1[nH]c(c(CCC(=O)[O-])c1C)Cc1[nH]c(c(CCC(=O)[O-])c1C)Cc1[nH]c(c(CCC(=O)[O-])c1C)C2': 1711,
#  'NC(CC[Se]CC(N)C(=O)O)C(=O)O': 1676,
#  'Oc1ccc(Cl)cc1Cl': 552,
#  'CCCCCCC1CCC(=O)O1': 225,
#  'C=Cc1ccc(O)c(OC)c1': 869,
#  'CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O[C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@H]2O)[C@@H]1O)[C@@H](O)C(=O)NCCC(=O)NCCS': 2956,
#  'CCCCCCCCCCCCCCCCCCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3264,
#  'COC(=O)C=Cc1ccccc1': 143,
#  'CCCCC': 19,
#  'CN(CC(=O)[O-])C(=[NH2+])NP(=O)([O-])[O-]': 1922,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCCC(C)=CCOP(=O)(O)OP(=O)(O)O': 808,
#  'O=c1[nH]cc([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c(=O)[nH]1': 1378,
#  'CSSc1ccoc1C': 3,
#  'CC(C)(COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-])[C@@H](O)C(=O)NCCC(=O)NCCS': 2848,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](CO)COC(=O)CCCCCCCCCCCCCCCCC': 1302,
#  'NCCc1ccccc1': 304,
#  'O=C([O-])C(=O)Cc1ccc(O)cc1': 1921,
#  'N=c1nc(O)c2c([nH]1)NCC(CNc1ccc(C(=O)NC(CCC(O)=NC(CCC(O)=NC(CCC(=O)O)C(=O)O)C(=O)O)C(=O)O)cc1)N2': 2393,
#  'O=CNC(Cc1ccc(O)c(-c2cc(CC(NC=O)C(=O)O)ccc2O)c1)C(=O)O': 1678,
#  'O=C(O)Cc1cc(O)ccc1O': 2037,
#  'CCc1csc(CC)n1': 4,
#  'COC1=CC(=O)C(C)=C(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)C1=O': 620,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O[C@H]1O[C@H](CO)[C@@H](O)C(O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 2771,
#  'OCc1cccs1': 152,
#  'CCCCCCCCCCCCCCCCCC(=O)[O-]': 723,
#  'O=Cc1ccco1': 120,
#  'CCC(CC)Nc1cc(C(=O)O)ccc1N1C(=O)CC[C@@]1(CN)CO': 1218,
#  'OC1CCCCC1': 613,
#  'O=C([O-])C1=CC(=O)[C@@H](O)[C@H](O)C1': 2393,
#  'CCCCCCCCCCCCCCC[C@@H](O)[C@H](CO)NC=O': 1537,
#  'NC(=O)NC(NC(N)=O)C(=O)[O-]': 643,
#  'O=C([O-])C(CO)OC1OC(COP(=O)([O-])O)C(O)C(O)C1O': 3001,
#  'COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2OC2OC(COC(=O)C=Cc3ccc(O)cc3)C(O)C(O)C2O)cc(OC)c1O': 3001,
#  'Nc1ncnc2c1ncn2C1OC(CO)C2OP(=O)(O)OC21': 1849,
#  'Cc1nc(C(=O)[O-])sc1CCOP(=O)([O-])OP(=O)([O-])OCC1OC(n2cnc3c(N)ncnc32)C(O)C1O': 2093,
#  'CC=CC(=O)C1=C(C)C=CCC1(C)C': 343,
#  'CSCC[C@H](NC(C)=O)C(=O)[O-]': 1555,
#  'Nc1nc2[nH]cnc2c(=O)[nH]1': 389,
#  '[NH3+][C@H](CO)Cc1c[nH]cn1': 1022,
#  'CCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](OC2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2538,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3258,
#  'CCCCCCC=CCCCCCCCC(=O)[O-]': 1040,
#  'CCOC(=O)C[C@@H](C)O': 1094,
#  'O=C1C=CC(=O)C=C1': 118,
#  'CC(C)C(C(=O)[O-])C(O)C(=O)[O-]': 1104,
#  'COc1c(Cl)cc(Cl)cc1Cl': 291,
#  'O=CNCC(=O)NC1OC(COP(=O)(O)O)C(O)C1O': 2311,
#  'NC(=NCCCC(N)C(=O)O)NC(CC(=O)O)C(=O)O': 1045,
#  'CCCCCCCCCC(=O)[O-]': 722,
#  '[NH3+][C@H](Cc1ccccc1)C(=O)[O-]': 1510,
#  'O=C(O)CCC1NC(C(=O)O)Cc2c1[nH]c1ccccc21': 1202,
#  'CCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3258,
#  'CC1SSC(C)S1': 0,
#  'O=C/C=C/c1ccccc1': 85,
#  'O=C([O-])c1ccc(O)cc1': 1240,
#  'O=C([O-])c1cc(O)c2ccccc2n1': 1798,
#  'O=C([O-])C(=O)[C@@H](O)[C@H](O)[C@H](O)CO': 2713,
#  'C[C@H](CO)C(=O)[O-]': 1202,
#  'C=CC=Cc1c(C)ccc(C)c1C': 26,
#  'O=C1C[C@@H](C(=O)[O-])NC(=O)N1': 1554,
#  'Nc1ncnc2c1ncn2C1OC2COP(=O)(O)OC2C1O': 1931,
#  'CC1(C)COC(=O)[C@@H]1O': 1378,
#  'CC(=O)c1ccccc1': 118,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC': 2460,
#  'C[C@@H](C(=O)O)[C@@H](O)C(=O)O': 1541,
#  'CC(C)(COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1O)C(O)C(=O)NCCC(=O)NCCS': 2561,
#  'C[C@@H](O)C(=O)[O-]': 1141,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)(O)OP(=O)(O)OCC1OC(n2ccc(N)nc2=O)C(O)C1O)OC(=O)CCCCCCCC=CCCCCCC': 2359,
#  'Cc1ccc(CS)o1': 12,
#  'CCCCCCCC/C=C/CCCCCCCC(=O)OC[C@H](COP(=O)(O)OCCNC)OC(=O)CCCCCCC/C=C/CCCCCCCC': 1304,
#  '[NH3+][C@@H](CCC[C@H]([NH3+])C(=O)[O-])C(=O)[O-]': 1679,
#  'CC(N)(CO)CO': 691,
#  'CCCCCC1CCC(=O)O1': 225,
#  'CCCCCCCCCCCCCCCCOCC(CO)OC(=O)CCCCCCCCCCCCCCC': 1227,
#  'CC(=O)N[C@@H](Cc1ccc(O)cc1)C(=O)O': 1872,
#  'O=C([O-])C(=O)C(C(=O)[O-])C(O)C(=O)[O-]': 1689,
#  'CCCCCCC=O': 322,
#  'CC(N)C(=O)NC(CCC(N)=O)C(=O)O': 2177,
#  'CCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O[C@@H]2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC': 2544,
#  'O=C(O)CCl': 762,
#  'C=CC1=C(C)/C(=C\\c2[nH]c(Cc3[nH]c(/C=C4/NC(=O)C(C)=C4C=C)c(C)c3CCC(=O)O)c(CCC(=O)O)c2C)NC1=O': 1706,
#  'O=C(/C=C\\c1ccc(O)c(O)c1)O[C@H](C(=O)O)[C@@H](O)C(=O)O': 2004,
#  'O=Cc1ccc2c(c1)OCO2': 223,
#  'O=C1O[C@H]([C@@H](O)CO)C(=O)C1=O': 1966,
#  'Cc1ccsc1': 7,
#  'C=C(C)c1ccccc1': 19,
#  'O=Cc1cccs1': 42,
#  'COc1cccc(OC)c1O': 880,
#  'C[S+](CCC(=O)C(=O)O)CC1OC(n2cnc3c(N)ncnc32)C(O)C1O': 2847,
#  'O=c1ccn([C@@H]2O[C@H](CO)[C@@H](OP(=O)([O-])[O-])[C@H]2O)c(=O)[nH]1': 2353,
#  'C=CC=O': 15,
#  'O=P([O-])(OC[C@H](O)CO)O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O': 2270,
#  'C[C@@H](OP(=O)([O-])[O-])[C@H]([NH3+])C(=O)[O-]': 2566,
#  'NCC(O)CCC(N)C(=O)O': 2578,
#  '[NH3+][C@H]1[C@@H](OP(=O)([O-])[O-])O[C@H](CO)[C@H](O)[C@@H]1O': 3023,
#  'CCCCCCCCCCCCCCCCCCC[C@@H](O)CC(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3301,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O[C@@H]2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2521,
#  'Cc1occc(=O)c1O': 796,
#  'CC1(C)CCCC2(C)OC(=O)C=C12': 207,
#  'CCCCCCCCCCCCCCCC(=O)OC[C@@H](O)COP(=O)([O-])[O-]': 2488,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H](COC(=O)CCCCCCCCCCCCCCC)COP(=O)([O-])OCC(O)COP(=O)([O-])OC[C@@H](COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCC/C=C\\CCCCCC': 2051,
#  'Oc1cc(O)c2cc(O)c(-c3cc(O)c(O)c(O)c3)[o+]c2c1': 1077,
#  'OCCCc1ccccc1': 604,
#  'CCC(=O)C(=O)[O-]': 1236,
#  'NC(=O)CCC(N)C(=O)O': 2142,
#  'NC(COP(=O)(O)O)C(=O)O': 2944,
#  'CCOC(=O)C(C)CC': 91,
#  'CCCCCC/C=C\\CCCCCCCC(=O)OC[C@H](COP(=O)([O-])[O-])OC(=O)CCCCCCC/C=C\\CCCCCCCC': 1295,
#  'CC(O)C(O)C1CN=C2N=C(N)NC(=O)C2(O)N1': 1300,
#  'O=C([O-])C(=O)CC(O)C(=O)[O-]': 2536,
#  'CC1=C(O)C(=O)CC1': 821,
#  'O=C(O)CCc1c[nH]c(Cc2[nH]c(Cc3[nH]c(Cc4[nH]c(CO)c(CC(=O)O)c4CCC(=O)O)c(CC(=O)O)c3CCC(=O)O)c(CC(=O)O)c2CCC(=O)O)c1CC(=O)O': 1720,
#  'CC(C)=CCC[C@@H](C)[C@H]1CC[C@@]2(C)C3=C(CC[C@]12C)[C@@]1(C)CC[C@H](O)C(C)(C)[C@@H]1CC3': 846,
#  'O=COCC(=O)OCCOP(=O)(O)OC1C(O)C(O)C(O)C(O)C1O': 1672,
#  'CC(C)=CCC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/CC/C(C)=C/COP(=O)([O-])OP(=O)([O-])[O-]': 808,
#  'O=C(O)CCCC(=O)C(=O)O': 2056,
#  'CCCCCCCCCCCCCCCCCCCCCCCC[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](OC2O[C@H](COP(=O)([O-])O[C@H]3[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]3O)[C@@H](O)[C@H](O)[C@@H]2O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@H](O)CCCCCCCCCCCCCC': 2538,
#  'O=C1C[C@@](O)(C(=O)[O-])C[C@@H](O)[C@@H]1O': 2538,
#  '[C-]#N': 18,
#  'O=C(O)c1cc(=O)[nH]c(=O)n1C1OC(COP(=O)(O)O)C(O)C1O': 2369,
#  'C=C(C)[C@H]1CC=C(C(=O)O)CC1': 793,
#  'O=c1[nH]cnc2c1ncn2[C@@H]1O[C@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])[O-])[C@@H](O)[C@H]1O': 2263,
#  'O=CC[C@@H](O)[C@H](O)[C@H](O)COP(=O)(O)O': 1470,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)(O)OCC(O)COP(=O)(O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCC=CCCCCCCCC)OC(=O)CCCCCCCC=CCCCCCC': 2255,
#  'CCC(=O)C(O)CC': 836,
#  'CCCCCCCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3301,
#  'CCOC(=O)CCSC': 267,
#  'CCc1oc(C)nc1C': 14,
#  'CCCCCCCCCCCCCCCCCCCCCCC(O)C(=O)N[C@@H](CO)[C@H](O)CCCCCCCCCCCCCCC': 1741,
#  'Cc1ncc(CO)c(=O)[nH]1': 1266,
#  'CCCCCCC=CCCCCCCCC(=O)OCC(COP(=O)(O)OCC(O)COP(=O)(O)OCC(COC(=O)CCCCCCCCCCCCCCC)OC(=O)CCCCCCCC=CCCCCCC)OC(=O)CCCCCCCC=CCCCCCCCC': 2255,
#  'O=C(COP(=O)(O)O)C(O)C(O)C(O)CO': 2691,
#  'O=c1[nH]c(=O)c2ncn(C3OC(COP(=O)(O)O)C(O)C3O)c2[nH]1': 2577,
#  'CC(=O)N[C@@H](CC(C)C)C(=O)[O-]': 1232,
#  'NCCCCCNCCCN': 343,
#  'Oc1cc(O)cc(C=Cc2ccc(O)c(O)c2)c1': 759,
#  'CC1=C(C)CC(C)(C=O)CC1': 302,
#  'CCCCCCCCCCCCCCCCCCCCC[C@@H](O)[C@H](O)C(=O)N[C@@H](COP(=O)([O-])O[C@H]1[C@H](O)[C@@H](O)[C@H](O)[C@@H](O)[C@H]1O)[C@H](O)[C@@H](O)CCCCCCCCCCCCCC': 2490,
#  'O=P([O-])([O-])OC[C@H]1O[C@H](OP(=O)([O-])OP(=O)([O-])[O-])[C@H](O)[C@@H]1O': 2802,
#  'CCCCCC(=O)CC': 359,
#  'CCOC=O': 24,
#  'COc1cc(/C=C\\C(=O)O)ccc1O': 1866,
#  'CCCCCCCCCCCC(=O)[O-]': 722,
#  'CSSSSC': 0,
#  'COc1c(O)c(C)c(CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)c(O)c1OC': 1018,
#  'CCCCCCCCCCCCCCCCCC(=O)CC(=O)SCCN=C(O)CCN=C(O)[C@H](O)C(C)(C)COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3446,
#  'CCCCCCCCC=CCC(O)CC(=O)SCCNC(=O)CCNC(=O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3306,
#  'O=P([O-])([O-])OC(CO)CO': 1942,
#  'O=C=O': 534,
#  '[NH3+][C@@H](CCC(=O)NCCCC(=O)[O-])C(=O)[O-]': 2372,
#  'NCC(=O)NC(CC(N)=O)C(=O)O': 2173,
#  'CCCCCCC=CCCCCCCCC(=O)OC(CO)COC(=O)CCCCCCCC=CCCCCCCCC': 1301,
#  'O=C1O[C@H]([C@@H](O)CO)C(=O)[C@@H]1O': 2063,
#  'CCCCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](COP(=O)(O)O[C@H]1C(O)C(O)C(O)[C@@H](O)C1O[C@H]1O[C@H](COP(=O)(O)O[C@H]2C(O)C(O)C(O)[C@@H](O)C2O)[C@@H](O)C(O)C1O)[C@H](O)CCCCCCCCCCCCCCC': 2527,
#  'Nc1ccn(C2OC(CO)C(O)C2OP(=O)(O)O)c(=O)n1': 2393,
#  'CCOC(=O)c1ccc(OCC)cc1': 248,
#  'Cc1cccc(C=O)c1': 207,
#  'O=C1OC(CO)C(O)=C1O': 1388,
#  'C=C(C=CC(C)C1CCC2C3=CC=C4CC(O)CCC4(C)C3CCC21C)C(C)C': 756,
#  'C[C@H](O)[C@H](C)O': 278,
#  'O=c1ccn([C@@H]2O[C@H](COP(=O)([O-])[O-])[C@@H](O)[C@H]2O)c(=O)[nH]1': 2266,
#  'CCCCCCCCCCCCCCCC(=O)OCC(O)COP(=O)([O-])OCC([NH3+])C(=O)[O-]': 3099,
#  'Cc1cn([C@H]2C[C@H](O)[C@@H](COP(=O)([O-])OP(=O)([O-])[O-])O2)c(=O)[nH]c1=O': 2304,
#  'CCCCCCCCCCCCCCCCCCCCCCCC(=O)CC(=O)SCCN=C(O)CCN=C(O)C(O)C(C)(C)COP(=O)(O)OP(=O)(O)OCC1OC(n2cnc3c(N)ncnc32)C(O)C1OP(=O)(O)O': 3446,
#  'OCc1ccco1': 499,
#  'CCCCCC/C=C\\CCCCCCCC(=O)O[C@H]1CC[C@]2(C)C3=C(CC[C@H]2C1)[C@@H]1CC[C@H]([C@H](C)CCC=C(C)C)[C@@]1(C)CC3': 372,
#  'O=C([O-])CCc1c2[nH]c(c1CC(=O)[O-])Cc1[nH]c(c(CC(=O)[O-])c1CCC(=O)[O-])Cc1[nH]c(c(CC(=O)[O-])c1CCC(=O)[O-])Cc1[nH]c(c(CC(=O)[O-])c1CCC(=O)[O-])C2': 1661,
#  'O=C(O)[C@H]1O[C@@H](Oc2c(-c3ccc(O)cc3)oc3cc(O)cc(O)c3c2=O)[C@H](O)[C@@H](O)[C@@H]1O': 2558,
#  'CCOC(=O)c1ccccc1O': 844,
#  'CC(=O)NCCC=O': 289,
#  'CC1=CC2OCC(C)C2CC1': 175,
#  'CC(C)=CCCC(C)=CCCC(C)=CCCC=C(C)CCC=C(C)CCC=C(C)C': 185,
#  'Cc1ccc(C)c2occc12': 69,
#  'COc1nccnc1C(C)C': 279,
#  'C=C1C=CCC(C)(C)C12CCC(C)O2': 172,
#  'NCCC(=O)O': 1377,
#  'CCCCCCCCCCCCCCCC(=O)OCC(O)COP(=O)(O)OCC[N+](C)(C)C': 2165,
#  'C[C@@H]1O[C@@H](O[C@@H]2C(=O)c3c(O)cc(O)cc3O[C@H]2c2ccc(O)c(O)c2)[C@H](O)[C@H](O)[C@H]1O': 2367,
#  'CC(C)(COP(=O)(O)OP(=O)(O)OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@@H](O)C1OP(=O)(O)O)[C@@H](O)C(=O)NCCC(=O)NCCSC(=O)c1ccc(O)cc1': 3671,
#  'COc1cccc(OC)c1': 333,
#  'CCCCCCCC/C=C/CCCCCCCC(=O)[O-]': 1040,
#  'C=C(OC1C=C(C(=O)O)C=CC1O)C(=O)O': 1351,
#  'CSCC1OC(OP(=O)(O)O)[C@H](O)[C@@H]1O': 3313,
#  'O=C([O-])c1cc(O)c2cccc(O)c2n1': 1847,
#  'CN(C)C(=[NH2+])NCCC[C@H]([NH3+])C(=O)[O-]': 1530,
#  'C[S+](C)CC[C@H]([NH3+])C(=O)[O-]': 2026,
#  'C[N+](C)(C)CCOP(=O)([O-])OC[C@H](O)CO': 2129,
#  'Cc1ncc2c(c1O)C(=O)OC2': 819,
#  'Cc1cnc(C(C)C)cn1': 33,
#  'Nc1nc2c(ncn2[C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(=O)[nH]c(N)nc54)[C@H](O)[C@@H]3O)[C@@H](O)[C@H]2O)c(=O)[nH]1': 1995,
#  'C=C([NH3+])C(=O)[O-]': 703,
#  'CCCCCC/C=C/C=O': 329,
#  'Cc1ncc(COP(=O)(O)O)c(C=O)c1O': 1849,
#  'CCc1cc(C)ccc1C': 55,
#  'O=C([O-])O': 166,
#  'O=c1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2O)c(=O)[nH]1': 1485,
#  'Nc1ccccc1C(=O)[O-]': 612,
#  'OCCCO': 679,
#  'CCCCCC/C=C\\CCCCC/C=C/C(=O)SCCNC(=O)CCNC(=O)[C@H](O)C(C)(C)COP(=O)([O-])OP(=O)([O-])OC[C@H]1O[C@@H](n2cnc3c(N)ncnc32)[C@H](O)[C@@H]1OP(=O)([O-])[O-]': 3265,
#  'O=CCC(O)C(O)C(O)CO': 1589,
#  'ClC(Cl)=C(Cl)Cl': 1,
#  'C/C=C/SC': 3,
#  'O=c1c(O)c(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12': 1171,
#  'COc1nccnc1CC(C)C': 302,
#  'COc1cc(C=O)ccc1OC(C)=O': 652,
#  'CCCCC[C@@H](O)CC(=O)[O-]': 1834,
#  'CC(C)[C@@H]([NH3+])C(=O)[O-]': 1115,
#  'Nc1nc2c(c(=O)[nH]1)NC(CNc1ccc(C(=O)NC(CCC(=O)NC(CCC(=O)O)C(=O)O)C(=O)O)cc1)CN2': 1361,
#  'COC(=O)c1ccc(O)c(OC)c1': 1050,
#  'C=C(CC[C@@H](C)[C@H]1CC[C@H]2C3=CC[C@H]4C[C@@H](O)CC[C@]4(C)[C@H]3CC[C@@]21C)C(C)C': 779,
#  'NC(=[NH2+])NCCCC(=O)[O-]': 784,
#  'O=C(O)C(O)Cc1ccc(O)cc1': 2641,
#  '[NH3+][C@@H](CC(=O)OP(=O)([O-])[O-])C(=O)[O-]': 2978,
#  ...}

# %%
# result = {'smiles':[],
#           'match_rules':[],
#           'reaction_num':[]}

# rxndb_total_info_to_model = pd.read_csv(rxndb_total_info_to_model_path)

# for smiles1,match_rules in tqdm(smiles_match_rules_dict.items(),total=len(smiles_match_rules_dict)):
#     reaction_num = 0 
#     for index,row in rxndb_total_info_to_model.iterrows():
#         smiles_lst = row['rxn_smiles_final'].replace('>>','.').split('.')
#         if any(compare_smiles_inchikey(smiles1,smiles2) for smiles2 in smiles_lst):
#             reaction_num+=1
#     result['smiles'].append(smiles1)       
#     result['match_rules'].append(match_rules)        
#     result['reaction_num'].append(reaction_num)

# %%
# Load data
rxndb_total_info_to_model = pd.read_csv(rxndb_total_info_to_model_path)

# Define the worker function
def match_smiles(smiles1_match_rules, rxndb_total_info_to_model):
    smiles1, match_rules = smiles1_match_rules
    reaction_num = 0 
    for index, row in rxndb_total_info_to_model.iterrows():
        smiles_lst = row['rxn_smiles_final'].replace('>>', '.').split('.')
        if any(compare_smiles_inchikey(smiles1, smiles2) for smiles2 in smiles_lst):
            reaction_num += 1
    return smiles1, match_rules, reaction_num

# Define the result dictionary
result = {'smiles': [], 'match_rules': [], 'reaction_num': []}

# Extract the task list for parallel processing
tasks = [(smiles1, match_rules) for smiles1, match_rules in smiles_match_rules_dict.items()]

# Set the number of processes
num_processes = 20
pool = multiprocessing.Pool(num_processes)

# Use partial to pass rxndb_total_info_to_model to match_smiles
match_smiles_partial = partial(match_smiles, rxndb_total_info_to_model=rxndb_total_info_to_model)

# Parallel processing
for smiles1, match_rules, reaction_num in tqdm(pool.imap(match_smiles_partial, tasks), total=len(tasks)):
    result['smiles'].append(smiles1)
    result['match_rules'].append(match_rules)
    result['reaction_num'].append(reaction_num)

# Close the process pool
pool.close()
pool.join()
# Out:
#   1%|          | 11/1457 [00:37<34:42,  1.44s/it]
# 100%|██████████| 1457/1457 [51:45<00:00,  2.13s/it]

# %%
result_df = pd.DataFrame(result)

# %%
# Calculate the correlation
correlation = result_df['match_rules'].corr(result_df['reaction_num'])
print(f"Correlation between match_rules and reaction_num: {correlation}")
# Out:
# Correlation between match_rules and reaction_num: 0.18246203417704315

# %%
# Assuming you want to sort by the 'score' column in descending order

result_df_sorted = result_df.sort_values(by='reaction_num', ascending=False)

result_df_sorted[~result_df_sorted['smiles'].str.contains('\.')]
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='O=C=O']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='NC(=O)c1ccc[n+]([C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](O)[C@@H]3O)[C@@H](O)[C@H]2O)c1']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='NC(=O)c1ccc[n+]([C@@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](OP(=O)([O-])[O-])[C@@H]3O)[C@@H](O)[C@H]2O)c1']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='NC(=O)C1=CN([C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](OP(=O)([O-])[O-])[C@@H]3O)[C@@H](O)[C@H]2O)C=CC1']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='NC(=O)C1=CN([C@H]2O[C@H](COP(=O)([O-])OP(=O)([O-])OC[C@H]3O[C@@H](n4cnc5c(N)ncnc54)[C@H](O)[C@@H]3O)[C@@H](O)[C@H]2O)C=CC1']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='C=O']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='CO']
result_df_sorted = result_df_sorted[result_df_sorted['smiles']!='CS']

# Calculate the correlation
correlation = result_df_sorted['match_rules'].corr(result_df_sorted['reaction_num'])
print(f"Correlation between match_rules and reaction_num: {correlation}")

result_df_sorted
# Out:
# Correlation between match_rules and reaction_num: 0.20046299973662204
#                                                  smiles  match_rules  \
# 1072  NC(=O)C1=CN(C2OC(COP(=O)(O)OP(=O)(O)OCC3OC(n4c...         2070
# 1292  NC(=O)C1=CN(C2OC(COP(=O)(O)OP(=O)(O)OCC3OC(n4c...         2334
# 386   Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O...         2269
# 1166             Nc1ncnc2c1ncn2C1OC(COP(=O)(O)O)C(O)C1O         2224
# 1109    Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)O)C(O)C1O         2283
# ...                                                 ...          ...
# 364   CCCCCCC=CCCCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCC...          344
# 372           CCCCCCCCCCCC[C@@H](O)[C@@H](O)[C@@H](N)CO         1545
# 373   CC(=O)OCC1OC(Oc2cc3c(O)cc(O)cc3[o+]c2-c2cc(O)c...         2828
# 1091                                  COc1cc(C)cc(OC)c1          357
# 728   COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2OC2OC(COC(C)=O)...         3056
#
#       reaction_num
# 1072           633
# 1292           617
# 386            563
# 1166           408
# 1109           396
# ...            ...
# 364              0
# 372              0
# 373              0
# 1091             0
# 728              0
#
# [1451 rows x 3 columns]

# %%
# Define a function to calculate the number of carbon atoms

def count_carbon_atoms(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    return sum(atom.GetAtomicNum() == 6 for atom in mol.GetAtoms())

# Apply the apply method to apply a function to a SMILES column in a DataFrame
result_df_sorted['carbon_count'] = result_df_sorted['smiles'].apply(count_carbon_atoms)
result_df_sorted
# Out:
#                                                  smiles  match_rules  \
# 1072  NC(=O)C1=CN(C2OC(COP(=O)(O)OP(=O)(O)OCC3OC(n4c...         2070
# 1292  NC(=O)C1=CN(C2OC(COP(=O)(O)OP(=O)(O)OCC3OC(n4c...         2334
# 386   Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)OP(=O)(O...         2269
# 1166             Nc1ncnc2c1ncn2C1OC(COP(=O)(O)O)C(O)C1O         2224
# 1109    Nc1ncnc2c1ncn2C1OC(COP(=O)(O)OP(=O)(O)O)C(O)C1O         2283
# ...                                                 ...          ...
# 364   CCCCCCC=CCCCCCCCCCC(=O)OCC(COC(=O)CCCCCCCCCCCC...          344
# 372           CCCCCCCCCCCC[C@@H](O)[C@@H](O)[C@@H](N)CO         1545
# 373   CC(=O)OCC1OC(Oc2cc3c(O)cc(O)cc3[o+]c2-c2cc(O)c...         2828
# 1091                                  COc1cc(C)cc(OC)c1          357
# 728   COc1cc(-c2[o+]c3cc(O)cc(O)c3cc2OC2OC(COC(C)=O)...         3056
#
#       reaction_num  carbon_count
# 1072           633            21
# 1292           617            21
# 386            563            10
# 1166           408            10
# 1109           396            10
# ...            ...           ...
# 364              0            55
# 372              0            16
# 373              0            23
# 1091             0             9
# 728              0            24
#
# [1451 rows x 4 columns]

# %%
result_df_sorted.to_csv(figs8_data_path,index=None)

# %%
from scipy.stats import pearsonr
# tmp1 = result_df_sorted[(result_df_sorted['Molecular_Weight']<200)&(result_df_sorted['Molecular_Weight']>50)]
# tmp2 = result_df_sorted[(result_df_sorted['Molecular_Weight']>200)|(result_df_sorted['Molecular_Weight']<50)]
tmp1 = result_df_sorted[(result_df_sorted['carbon_count']<9)&(result_df_sorted['carbon_count']>3)]
tmp2 = result_df_sorted[(result_df_sorted['carbon_count']>9)|(result_df_sorted['carbon_count']<3)]
# 计算相关系数和 p 值
correlation, p_value = pearsonr(tmp1['match_rules'], tmp1['reaction_num'])

print(f"Correlation coefficient: {correlation}")
print(f"P-value: {p_value}")

# 计算相关系数和 p 值
correlation, p_value = pearsonr(tmp2['match_rules'], tmp2['reaction_num'])

print(f"Correlation coefficient: {correlation}")
print(f"P-value: {p_value}")
# Out:
# Correlation coefficient: 0.4049008117852858
# P-value: 4.6896787439534494e-24
# Correlation coefficient: 0.09942283334779192
# P-value: 0.00824856469809552

# %%
import matplotlib.pyplot as plt
import numpy as np

# Setting General Parameters
plt.figure(figsize=(2.5, 2.5), dpi=400)
plt.rcParams.update({'font.size': 8})
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['pdf.fonttype'] = 42

# Setting Axis Styles
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.gca().spines['top'].set_linewidth(0.5)
plt.gca().spines['bottom'].set_linewidth(0.5)
plt.gca().spines['left'].set_linewidth(0.5)
plt.gca().spines['right'].set_linewidth(0.5)

# Adjusting the size of scatter points (s parameter) and using normalized 'score'
plt.scatter(tmp1['match_rules'], tmp1['reaction_num'], 
            s=4,  # Size of the points
            c='#40004b',  # Color of the points
            edgecolor='#40004b',  # Border color of the points
            linewidth=0.25,  # Border width of the points
            alpha=0.4,  # Transparency of the points
            label='Carbon(3~9), r = 0.41, N = 746'  # Label
           )

plt.scatter(tmp2['match_rules'], tmp2['reaction_num'], 
            s=4,  # Size of the points
            c='#f46d43',  # Color of the points
            edgecolor='#f46d43',  # Border color of the points
            linewidth=0.25,  # Border width of the points
            alpha=0.4,  # Transparency of the points
            label='Carbon(<3,>9), r = 0.10, N = 706'  # Label
           )

# Setting X-axis Labels
plt.xlabel('Metabolites match rules number', fontsize=8)
plt.ylabel('Metabolites participate reaction number', fontsize=8)

plt.xlim(9, 4000)
plt.ylim(0.9, 1000)
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.xscale('log')  # Set x-axis to logarithmic scale
plt.minorticks_off()  # Hide minor ticks

plt.tick_params(axis='both', direction='in', width=0.5, which='both', length=2)

# Adding Legend
plt.legend(frameon=False, fontsize=8, loc='center left', bbox_to_anchor=(-0.05, 0.9), ncol=1, labelspacing=0.5, handletextpad=0.3, handlelength=1)

# Save the figure to a file
plt.savefig(figs8_path, dpi=400, bbox_inches='tight')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped
